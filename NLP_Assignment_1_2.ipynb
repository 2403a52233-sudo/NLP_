# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52233-sudo/NLP_/blob/main/NLP_Assignment_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy
import nltk
import spacy
nltk.download('punkt')
nlp = spacy.load("en_core_web_sm")
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = """"Machine learning is a subset of artificial intelligence
that focuses on building systems that can learn from data
and improve their performance over time."""

text_lowercase = text.lower()

tokens = nltk.word_tokenize(text_lowercase)
word_count = len(tokens)

print(f"Original Text:\n{text}\n")
print(f"Lowercased Text:\n{text_lowercase}\n")
print(f"Total Word Count: {word_count}")
# Out:
# Original Text:
# "Machine learning is a subset of artificial intelligence
# that focuses on building systems that can learn from data
# and improve their performance over time.
#
# Lowercased Text:
# "machine learning is a subset of artificial intelligence
# that focuses on building systems that can learn from data
# and improve their performance over time.
#
# Total Word Count: 26
